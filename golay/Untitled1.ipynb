# %%
import keras
from keras.models import load_model
from keras.models import Model
from keras.utils import plot_model

# %%
model_p5 = load_model('model_p5_v2.h5')
model_p6 = load_model('model_p6.h5')
model_p7 = load_model('model_p7.h5')
model_p8 = load_model('model_p8.h5')

# %%
model_p5.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 23)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 46)           1104        input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 69)           1656        input_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 92)           2208        input_1[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 115)          2760        input_1[0][0]
# ...

# %%
plot_model(model_p5, to_file='p5.png')

# %%
plot_model(model_p6, to_file='p6.png')
plot_model(model_p7, to_file='p8.png')
plot_model(model_p8, to_file='p7png')
